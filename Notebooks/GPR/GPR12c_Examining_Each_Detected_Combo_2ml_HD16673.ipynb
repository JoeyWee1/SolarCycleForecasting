# %% [markdown]
# # Examining how the pipeline performs with each detected combination.
#
# - Let's examine one of each manually and make the pipeline work for them.
# - 3sml: hd18256
# - 2sm: hd10072
# - 2ml: hd16673
# - 1m: hd11131
# - 0: hd10700

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import minimize

import celerite2
from celerite2 import terms

from prettytable import PrettyTable

import sys
from pathlib import Path

sys.path.append(str(Path('../..').resolve()))

from helpers.df_ops import prepare_df, split_df, clean_df
from helpers.priors import find_classify_signals, get_priors

SEED = 1701
error_percent = 5

# %%
from helpers.gpr import train_gpr

datapath = r"../../Data/hd16673_caii.txt"
add_prefix = True
relative = True
train_split = 0.8
valid_split = 0.19

require_mid = True
sigma_upper_mult = 5
rho_bound_mults = [0.9, 1.1]
q_bounds_in = [5, 10]
loop_verbose = False
loop_plot = False
loop_savefigs = False
star_name = "HD16673"
star_type = "F"
results_verbose = True
results_plot = True
ax = None

# Window analysis using refactored train_gpr
def plot_moving_window(n_windows=10, train_low=0.1, train_high=0.9):
    fig, axes = plt.subplots(n_windows, 1, figsize=(20, 5 * n_windows), sharex=True, sharey=True)
    train_splits = np.linspace(train_low, train_high, n_windows)

    for idx, ts in enumerate(train_splits):
        print(f"{idx+1}/{n_windows}")
        train_gpr(
            datapath         = datapath,
            add_prefix       = add_prefix,
            relative         = relative,
            train_split      = ts,
            valid_split      = 0.99 - ts,
            star_name        = star_name,
            star_type        = star_type,
            error_percent    = error_percent,
            sigma_upper_mult = sigma_upper_mult,
            q_bounds_in      = q_bounds_in,
            require_mid      = require_mid,
            verbose          = False,
            plot             = False,
            loop_verbose     = loop_verbose,
            loop_plot        = loop_plot,
            loop_savefigs    = loop_savefigs,
            results_verbose  = results_verbose,
            results_plot     = results_plot,
            ax               = axes[idx],
            SEED             = SEED,
        )

    plt.tight_layout()
    plt.savefig(f"moving_window_{star_name}")
    plt.show()

plot_moving_window()
# Out:
# 1/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 1510.48 days was accepted.
# In iteration 1, period at 270.57 days was accepted.
# In iteration 2, period at 332.98 days was accepted.
# The best params were found for const with NLPD of -3.212131932384838.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0077 | 0.50 |  1359.43   |     3.72    |
# +--------+------+------------+-------------+
# 2/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# Period of 273.85 days has SNR of 4.964482850499082 < 5.
# Period of 294.66 days has SNR of 4.147027154002544 < 5.
# In iteration 0, period at 1537.13 days was accepted.
# Period of 274.58 days has SNR of 4.78308856844943 < 5.
# Peak at period 63.25 days was identified to be a window of 60.88 days by tolerance 0.04.
# In iteration 1, period at 140.26 days was accepted.
# Peak at period 63.25 days was identified to be a window of 60.88 days by tolerance 0.04.
# Iteration 2 did not find a frequency: terminating loop.
# The best params were found for const with NLPD of -3.1993542197616964.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0083 | 0.50 |  1383.41   |     3.79    |
# +--------+------+------------+-------------+
# 3/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 1456.46 days was accepted.
# Peak at period 378.61 days was identified to be an alias of 1456.46 days at mult 0.25 by tolerance 0.04.
# Peak at period 4288.52 days was identified to be an alias of 1456.46 days at mult 3.00 by tolerance 0.02.
# Period of 333.35 days has SNR of 4.551983631034265 < 5.
# Peak at period 191.36 days was identified to be a window of 182.62 days by tolerance 0.05.
# Peak at period 185.16 days was identified to be a window of 182.62 days by tolerance 0.01.
# In iteration 1, period at 273.12 days was accepted.
# Peak at period 4375.02 days was identified to be an alias of 1456.46 days at mult 3.00 by tolerance 0.00.
# In iteration 2, period at 7191.75 days was accepted.
# Peak at period 63.25 days was identified to be a window of 60.88 days by tolerance 0.04.
# Period of 329.33 days has SNR of 4.388500816517483 < 5.
# In iteration 3, period at 970.64 days was accepted.
# Peak at period 328.60 days was identified to be an alias of 970.64 days at mult 0.33 by tolerance 0.02.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 41.71 days has SNR of nan < 5.
# Peak at period 62.88 days was identified to be a window of 60.88 days by tolerance 0.03.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 37.33 days has SNR of nan < 5.
# Period of 76.39 days has SNR of 4.738951116173337 < 5.
# Peak at period 3547.93 days was identified to be an alias of 7191.75 days at mult 0.50 by tolerance 0.01.
# Peak at period 359.99 days was identified to be an alias of 1456.46 days at mult 0.25 by tolerance 0.01.
# Iteration 4 did not find a frequency: terminating loop.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# The best params were found for 2ml with NLPD of -3.208703008797315.
# +--------+-------+------------+-------------+
# | sigma  |   Q   | rho (days) | rho (years) |
# +--------+-------+------------+-------------+
# | 0.0085 |  5.00 |  1310.81   |     3.59    |
# | 0.0034 | 10.00 |  9596.53   |    26.29    |
# +--------+-------+------------+-------------+
# 4/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 4723.23 days was accepted.
# In iteration 1, period at 292.10 days was accepted.
# In iteration 2, period at 1052.77 days was accepted.
# Peak at period 349.41 days was identified to be an alias of 1052.77 days at mult 0.33 by tolerance 0.00.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 37.33 days has SNR of nan < 5.
# Peak at period 174.21 days was identified to be a window of 182.62 days by tolerance 0.05.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 41.35 days has SNR of nan < 5.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 46.82 days has SNR of nan < 5.
# Iteration 3 did not find a frequency: terminating loop.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# The best params were found for 2sm with NLPD of -3.22811106484482.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0050 | 5.00 |   159.86   |     0.44    |
# | 0.0082 | 5.00 |  5195.56   |    14.23    |
# +--------+------+------------+-------------+
# 5/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 4579.06 days was accepted.
# In iteration 1, period at 292.47 days was accepted.
# In iteration 2, period at 1037.07 days was accepted.
# Peak at period 372.40 days was identified to be a window of 365.25 days by tolerance 0.02.
# Peak at period 350.87 days was identified to be an alias of 1037.07 days at mult 0.33 by tolerance 0.01.
# Peak at period 143.55 days was identified to be an alias of 292.47 days at mult 0.50 by tolerance 0.02.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 37.33 days has SNR of nan < 5.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 33.68 days has SNR of nan < 5.
# Peak at period 13316.49 days was identified to be an alias of 4579.06 days at mult 3.00 by tolerance 0.03.
# Iteration 3 did not find a frequency: terminating loop.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# The best params were found for 2sm with NLPD of -3.176959106369351.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0039 | 5.00 |   86.18    |     0.24    |
# | 0.0087 | 5.00 |  4121.15   |    11.29    |
# +--------+------+------------+-------------+
# 6/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 5214.89 days was accepted.
# In iteration 1, period at 1499.17 days was accepted.
# Peak at period 371.31 days was identified to be an alias of 1499.17 days at mult 0.25 by tolerance 0.01.
# Period of 275.68 days has SNR of 4.531243575128412 < 5.
# Period of 147.56 days has SNR of 4.0551873568790295 < 5.
# Peak at period 184.43 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 352.69 days was identified to be a window of 365.25 days by tolerance 0.03.
# In iteration 2, period at 570.23 days was accepted.
# Peak at period 275.31 days was identified to be an alias of 570.23 days at mult 0.50 by tolerance 0.03.
# Peak at period 372.40 days was identified to be an alias of 1499.17 days at mult 0.25 by tolerance 0.01.
# Peak at period 144.28 days was identified to be an alias of 570.23 days at mult 0.25 by tolerance 0.01.
# Peak at period 147.20 days was identified to be an alias of 570.23 days at mult 0.25 by tolerance 0.03.
# Period of 239.54 days has SNR of 3.603044909588541 < 5.
# Peak at period 184.79 days was identified to be an alias of 570.23 days at mult 0.33 by tolerance 0.03.
# Period of 157.05 days has SNR of 3.376061042032962 < 5.
# Peak at period 353.42 days was identified to be a window of 365.25 days by tolerance 0.03.
# Period of 105.22 days has SNR of 2.760226470092945 < 5.
# Peak at period 189.54 days was identified to be an alias of 570.23 days at mult 0.33 by tolerance 0.00.
# Peak at period 1099.85 days was identified to be an alias of 570.23 days at mult 2.00 by tolerance 0.04.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 37.33 days has SNR of nan < 5.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 39.52 days has SNR of nan < 5.
# Period of 398.32 days has SNR of 4.0588909711040975 < 5.
# Iteration 3 did not find a frequency: terminating loop.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# The best params were found for 2sm with NLPD of -3.2700336692427316.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0056 | 5.00 |   306.72   |     0.84    |
# | 0.0041 | 5.00 |  5736.38   |    15.72    |
# +--------+------+------------+-------------+
# 7/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 5800.72 days was accepted.
# Peak at period 1491.50 days was identified to be an alias of 5800.72 days at mult 0.25 by tolerance 0.03.
# Peak at period 184.43 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 369.12 days was identified to be a window of 365.25 days by tolerance 0.01.
# In iteration 1, period at 291.01 days was accepted.
# In iteration 2, period at 332.62 days was accepted.
# Peak at period 1029.41 days was identified to be an alias of 332.62 days at mult 3.00 by tolerance 0.03.
# Peak at period 574.61 days was identified to be an alias of 291.01 days at mult 2.00 by tolerance 0.01.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 39.52 days has SNR of nan < 5.
# Peak at period 143.55 days was identified to be an alias of 291.01 days at mult 0.50 by tolerance 0.01.
# Peak at period 123.47 days was identified to be a window of 121.75 days by tolerance 0.01.
# Period of 273.12 days has SNR of 4.624158499871279 < 5.
# In iteration 3, period at 1599.54 days was accepted.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 39.52 days has SNR of nan < 5.
# Peak at period 123.11 days was identified to be a window of 121.75 days by tolerance 0.01.
# Peak at period 143.55 days was identified to be an alias of 291.01 days at mult 0.50 by tolerance 0.01.
# Peak at period 184.43 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 116.90 days was identified to be a window of 121.75 days by tolerance 0.04.
# Peak at period 63.25 days was identified to be a window of 60.88 days by tolerance 0.04.
# Peak at period 373.13 days was identified to be a window of 365.25 days by tolerance 0.02.
# Iteration 4 did not find a frequency: terminating loop.
# The best params were found for 3sml with NLPD of -3.1683043902043457.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0067 | 5.00 |  1057.02   |     2.90    |
# | 0.0030 | 5.00 |  5220.65   |    14.30    |
# | 0.0021 | 5.00 |  34225.56  |    93.77    |
# +--------+------+------------+-------------+
# 8/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2207.64 days was accepted.
# In iteration 1, period at 288.45 days was accepted.
# Peak at period 372.40 days was identified to be a window of 365.25 days by tolerance 0.02.
# Peak at period 183.70 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 123.11 days was identified to be a window of 121.75 days by tolerance 0.01.
# Period of 338.46 days has SNR of 2.7380351067592077 < 5.
# In iteration 2, period at 10149.00 days was accepted.
# Peak at period 181.87 days was identified to be a window of 182.62 days by tolerance 0.00.
# Peak at period 365.47 days was identified to be a window of 365.25 days by tolerance 0.00.
# In iteration 3, period at 335.54 days was accepted.
# Peak at period 184.79 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 370.58 days was identified to be a window of 365.25 days by tolerance 0.01.
# Peak at period 578.63 days was identified to be an alias of 2207.64 days at mult 0.25 by tolerance 0.05.
# Peak at period 859.68 days was identified to be an alias of 288.45 days at mult 3.00 by tolerance 0.01.
# Peak at period 998.38 days was identified to be an alias of 335.54 days at mult 3.00 by tolerance 0.01.
# Peak at period 123.11 days was identified to be a window of 121.75 days by tolerance 0.01.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 33.68 days has SNR of nan < 5.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 39.52 days has SNR of nan < 5.
# Period of 637.39 days has SNR of 4.252324937645513 < 5.
# Peak at period 142.82 days was identified to be an alias of 288.45 days at mult 0.50 by tolerance 0.01.
# Period of 157.05 days has SNR of 3.795319036642719 < 5.
# Period of 415.47 days has SNR of 3.730332747283959 < 5.
# Iteration 4 did not find a frequency: terminating loop.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# The best params were found for 3sml with NLPD of -3.0211501155135694.
# +--------+-------+------------+-------------+
# | sigma  |   Q   | rho (days) | rho (years) |
# +--------+-------+------------+-------------+
# | 0.0001 |  6.78 |    0.11    |     0.00    |
# | 0.0145 |  5.00 |  1986.87   |     5.44    |
# | 0.0024 | 10.00 |  11163.90  |    30.59    |
# +--------+-------+------------+-------------+
# 9/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2314.95 days was accepted.
# Peak at period 375.69 days was identified to be a window of 365.25 days by tolerance 0.03.
# In iteration 1, period at 278.23 days was accepted.
# Peak at period 376.42 days was identified to be a window of 365.25 days by tolerance 0.03.
# In iteration 2, period at 996.19 days was accepted.
# Peak at period 377.51 days was identified to be a window of 365.25 days by tolerance 0.03.
# In iteration 3, period at 11637.48 days was accepted.
# Peak at period 181.14 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 337.00 days was identified to be an alias of 996.19 days at mult 0.33 by tolerance 0.01.
# Peak at period 363.28 days was identified to be a window of 365.25 days by tolerance 0.01.
# Peak at period 185.52 days was identified to be a window of 182.62 days by tolerance 0.02.
# In iteration 4, period at 3457.41 days was accepted.
# In iteration 5, period at 1379.08 days was accepted.
# Peak at period 124.57 days was identified to be a window of 121.75 days by tolerance 0.02.
# Peak at period 186.98 days was identified to be a window of 182.62 days by tolerance 0.02.
# Peak at period 181.51 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 361.45 days was identified to be an alias of 1379.08 days at mult 0.25 by tolerance 0.05.
# Peak at period 93.54 days was identified to be an alias of 278.23 days at mult 0.33 by tolerance 0.01.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 33.68 days has SNR of nan < 5.
# Iteration 6 did not find a frequency: terminating loop.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# The best params were found for 2sm with NLPD of -3.1632199739105107.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0001 | 5.00 |    0.17    |     0.00    |
# | 0.0173 | 5.00 |  2083.45   |     5.71    |
# +--------+------+------------+-------------+
# 10/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2388.31 days was accepted.
# In iteration 1, period at 279.33 days was accepted.
# Peak at period 375.69 days was identified to be a window of 365.25 days by tolerance 0.03.
# In iteration 2, period at 16289.44 days was accepted.
# Peak at period 184.79 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 368.02 days was identified to be a window of 365.25 days by tolerance 0.01.
# In iteration 3, period at 1002.03 days was accepted.
# Peak at period 337.00 days was identified to be an alias of 1002.03 days at mult 0.33 by tolerance 0.01.
# Peak at period 185.16 days was identified to be a window of 182.62 days by tolerance 0.01.
# Peak at period 366.93 days was identified to be a window of 365.25 days by tolerance 0.00.
# Peak at period 181.87 days was identified to be a window of 182.62 days by tolerance 0.00.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 33.68 days has SNR of nan < 5.
# Peak at period 123.84 days was identified to be a window of 121.75 days by tolerance 0.02.
# Peak at period 3903.07 days was identified to be an alias of 16289.44 days at mult 0.25 by tolerance 0.04.
# Period of 77.12 days has SNR of 4.708596282687654 < 5.
# In iteration 4, period at 1363.75 days was accepted.
# c:\Users\Joey\Desktop\Cambridge\Work\Thesis\VenvThesis\lib\site-packages\numpy\_core\_methods.py:191: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# Peak at period 336.63 days was identified to be an alias of 1002.03 days at mult 0.33 by tolerance 0.01.
# Peak at period 365.83 days was identified to be a window of 365.25 days by tolerance 0.00.
# Peak at period 184.79 days was identified to be a window of 182.62 days by tolerance 0.01.
# In iteration 5, period at 3708.16 days was accepted.
# Peak at period 181.87 days was identified to be a window of 182.62 days by tolerance 0.00.
# Peak at period 185.52 days was identified to be a window of 182.62 days by tolerance 0.02.
# Peak at period 124.20 days was identified to be a window of 121.75 days by tolerance 0.02.
# SNR failed to fit Gaussian. Fell back to height vs average.
# Period of 33.68 days has SNR of nan < 5.
# Peak at period 364.74 days was identified to be a window of 365.25 days by tolerance 0.00.
# Peak at period 93.54 days was identified to be an alias of 279.33 days at mult 0.33 by tolerance 0.00.
# Period of 77.12 days has SNR of 3.817889213489766 < 5.
# Peak at period 1891.18 days was identified to be an alias of 3708.16 days at mult 0.50 by tolerance 0.02.
# Iteration 6 did not find a frequency: terminating loop.
# The best params were found for 2ml with NLPD of -3.3628659935939784.
# +--------+-------+------------+-------------+
# | sigma  |   Q   | rho (days) | rho (years) |
# +--------+-------+------------+-------------+
# | 0.0194 |  5.00 |  2149.48   |     5.89    |
# | 0.0012 | 10.00 |  15238.77  |    41.75    |
# +--------+-------+------------+-------------+

# %% [markdown]
# - Once again, I think it is important to introduce a factor of the model uncertainty using an MCMC.
