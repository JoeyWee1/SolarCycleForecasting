# %% [markdown]
# # Pipeline Moving Window
# - Here, we perform moving window analysis using the pipeline code fit at various datasplits.

# %%
# Importing and data hopo hopo
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
from pathlib import Path

sys.path.append(str(Path('../..').resolve()))
from helpers.gpr import train_gpr

# %%
def plot_moving_window( n_windows = 10, train_low = 0.1, train_high = 0.9):
    fig, ax = plt.subplots(n_windows, 1, figsize=(20, 5 * n_windows), sharex= True, sharey= True)
    train_splits = np.linspace(train_low, train_high, n_windows)       

    for idx, train_split in enumerate(train_splits):
        print(f"{idx+1}/{n_windows}")
        valid_split = 0.99 - train_split
        best_gp = train_gpr(
        datapath    =  r"../../Data/benchmark/HD201091_Mt_wilson_data.txt",
        train_split=train_split,
        valid_split=valid_split,
        star_name   = 'HD201091',
        star_type   = 'G',
        add_prefix  = False,
        relative=True,
        verbose          = False,
        plot             = False,
        loop_verbose     = False,
        loop_plot        = True,
        loop_savefigs    = True,   # show inline rather than saving
        results_verbose  = True,
        results_plot     = True,
        ax = ax[idx]
    )
    
    plt.show()

plot_moving_window()
# Out:
# 1/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2551.47 days was accepted.
# In iteration 1, period at 39.52 days was accepted.
# In iteration 2, period at 37.33 days was accepted.
# In iteration 3, period at 1628.01 days was accepted.
# Peak at period 17287.36 days is greater than maximum detectable period of 14223.126029999927 days.
# Peak at period 381.89 days was identified to be a window of 365.25 days by tolerance 0.05.
# Peak at period 667.69 days was identified to be an alias of 2551.47 days at mult 0.25 by tolerance 0.05.
# Iteration 4 did not find a frequency: terminating loop.
# The best params were found for 3sml with NLPD of -1.0470004769310737.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0404 | 5.00 |   36.95    |     0.10    |
# | 0.1140 | 5.00 |  2296.32   |     6.29    |
# | 0.0001 | 5.00 |  32850.00  |    90.00    |
# +--------+------+------------+-------------+
# 2/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2197.05 days was accepted.
# Peak at period 4319.54 days was identified to be an alias of 2197.05 days at mult 2.00 by tolerance 0.02.
# In iteration 1, period at 39.52 days was accepted.
# Peak at period 4273.92 days was identified to be an alias of 2197.05 days at mult 2.00 by tolerance 0.03.
# In iteration 2, period at 384.45 days was accepted.
# In iteration 3, period at 4093.97 days was accepted.
# In iteration 4, period at 1677.65 days was accepted.
# Peak at period 96.83 days was identified to be an alias of 384.45 days at mult 0.25 by tolerance 0.01.
# In iteration 5, period at 639.58 days was accepted.
# Peak at period 96.83 days was identified to be an alias of 384.45 days at mult 0.25 by tolerance 0.01.
# Peak at period 94.27 days was identified to be an alias of 384.45 days at mult 0.25 by tolerance 0.02.
# Period of 142.09 days has SNR of 4.826089774978735 < 5.
# Peak at period 61.42 days was identified to be a window of 60.88 days by tolerance 0.01.
# Period of 68.36 days has SNR of 4.092614718740127 < 5.
# Period of 37.33 days has SNR of 4.155409788519942 < 5.
# Peak at period 78.94 days was identified to be an alias of 39.52 days at mult 2.00 by tolerance 0.00.
# Period of 66.53 days has SNR of 3.7808758967721245 < 5.
# Period of 70.55 days has SNR of 3.7653473084888436 < 5.
# Period of 36.24 days has SNR of 3.693900013404615 < 5.
# Peak at period 76.39 days was identified to be an alias of 39.52 days at mult 2.00 by tolerance 0.03.
# Period of 73.83 days has SNR of 3.474119933177975 < 5.
# Peak at period 81.50 days was identified to be an alias of 39.52 days at mult 2.00 by tolerance 0.03.
# Iteration 6 did not find a frequency: terminating loop.
# The best params were found for 2ls with NLPD of -1.0167965338970666.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0043 | 5.00 |  32850.00  |    90.00    |
# | 0.0943 | 5.00 |   35.57    |     0.10    |
# +--------+------+------------+-------------+
# 3/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2220.78 days was accepted.
# Peak at period 4442.55 days was identified to be an alias of 2220.78 days at mult 2.00 by tolerance 0.00.
# In iteration 1, period at 39.52 days was accepted.
# Peak at period 4426.49 days was identified to be an alias of 2220.78 days at mult 2.00 by tolerance 0.00.
# In iteration 2, period at 392.11 days was accepted.
# Peak at period 4255.67 days was identified to be an alias of 2220.78 days at mult 2.00 by tolerance 0.04.
# In iteration 3, period at 332.98 days was accepted.
# Peak at period 4469.19 days was identified to be an alias of 2220.78 days at mult 2.00 by tolerance 0.01.
# In iteration 4, period at 33.68 days was accepted.
# Peak at period 4568.47 days was identified to be an alias of 2220.78 days at mult 2.00 by tolerance 0.03.
# Peak at period 640.68 days was identified to be an alias of 332.98 days at mult 2.00 by tolerance 0.04.
# Peak at period 187.35 days was identified to be an alias of 392.11 days at mult 0.50 by tolerance 0.04.
# Peak at period 28.57 days was identified to be a window of 29.50 days by tolerance 0.03.
# Iteration 5 did not find a frequency: terminating loop.
# The best params were found for 2ls with NLPD of -1.0248033465703947.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0029 | 5.01 |  32850.00  |    90.00    |
# | 0.0936 | 5.00 |   35.57    |     0.10    |
# +--------+------+------------+-------------+
# 4/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2184.64 days was accepted.
# Peak at period 4257.49 days was identified to be an alias of 2184.64 days at mult 2.00 by tolerance 0.03.
# In iteration 1, period at 500.15 days was accepted.
# Peak at period 4160.40 days was identified to be an alias of 2184.64 days at mult 2.00 by tolerance 0.05.
# In iteration 2, period at 39.52 days was accepted.
# In iteration 3, period at 4142.88 days was accepted.
# In iteration 4, period at 36.24 days was accepted.
# In iteration 5, period at 1665.24 days was accepted.
# In iteration 6, period at 645.79 days was accepted.
# In iteration 7, period at 46.46 days was accepted.
# Peak at period 183.33 days was identified to be an alias of 46.46 days at mult 4.00 by tolerance 0.01.
# Peak at period 356.34 days was identified to be a window of 365.25 days by tolerance 0.02.
# Iteration 8 did not find a frequency: terminating loop.
# The best params were found for 2ls with NLPD of -1.104945155712715.
# +--------+--------+------------+-------------+
# | sigma  |   Q    | rho (days) | rho (years) |
# +--------+--------+------------+-------------+
# | 0.0252 | 100.00 |  32850.00  |    90.00    |
# | 0.0881 |  5.00  |   35.57    |     0.10    |
# +--------+--------+------------+-------------+
# 5/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2412.04 days was accepted.
# In iteration 1, period at 1326.52 days was accepted.
# Peak at period 7371.33 days was identified to be an alias of 2412.04 days at mult 3.00 by tolerance 0.02.
# Peak at period 351.23 days was identified to be a window of 365.25 days by tolerance 0.04.
# Peak at period 785.22 days was identified to be an alias of 2412.04 days at mult 0.33 by tolerance 0.02.
# Peak at period 381.16 days was identified to be a window of 365.25 days by tolerance 0.04.
# Period of 208.15 days has SNR of 4.291531880702137 < 5.
# Peak at period 679.37 days was identified to be an alias of 1326.52 days at mult 0.50 by tolerance 0.02.
# Period of 239.54 days has SNR of 4.103894894957006 < 5.
# Period of 159.97 days has SNR of 3.692226893702958 < 5.
# In iteration 2, period at 489.20 days was accepted.
# Peak at period 7461.48 days was identified to be an alias of 2412.04 days at mult 3.00 by tolerance 0.03.
# Peak at period 675.35 days was identified to be an alias of 1326.52 days at mult 0.50 by tolerance 0.02.
# Peak at period 781.94 days was identified to be an alias of 2412.04 days at mult 0.33 by tolerance 0.03.
# Peak at period 351.60 days was identified to be a window of 365.25 days by tolerance 0.04.
# Peak at period 239.54 days was identified to be an alias of 489.20 days at mult 0.50 by tolerance 0.02.
# Peak at period 381.53 days was identified to be a window of 365.25 days by tolerance 0.04.
# In iteration 3, period at 39.52 days was accepted.
# Peak at period 7482.29 days was identified to be an alias of 2412.04 days at mult 3.00 by tolerance 0.03.
# Peak at period 673.89 days was identified to be an alias of 1326.52 days at mult 0.50 by tolerance 0.02.
# Peak at period 351.60 days was identified to be a window of 365.25 days by tolerance 0.04.
# Peak at period 781.21 days was identified to be an alias of 2412.04 days at mult 0.33 by tolerance 0.03.
# In iteration 4, period at 35.14 days was accepted.
# Peak at period 7304.90 days was identified to be an alias of 2412.04 days at mult 3.00 by tolerance 0.01.
# Peak at period 673.16 days was identified to be an alias of 1326.52 days at mult 0.50 by tolerance 0.01.
# Peak at period 239.18 days was identified to be an alias of 489.20 days at mult 0.50 by tolerance 0.02.
# Peak at period 780.84 days was identified to be an alias of 2412.04 days at mult 0.33 by tolerance 0.03.
# Peak at period 352.33 days was identified to be a window of 365.25 days by tolerance 0.04.
# Peak at period 382.99 days was identified to be a window of 365.25 days by tolerance 0.05.
# In iteration 5, period at 227.86 days was accepted.
# Peak at period 7220.58 days was identified to be an alias of 2412.04 days at mult 3.00 by tolerance 0.00.
# Peak at period 69.09 days was identified to be an alias of 35.14 days at mult 2.00 by tolerance 0.02.
# Peak at period 353.42 days was identified to be a window of 365.25 days by tolerance 0.03.
# Period of 32.59 days has SNR of 4.934121570236495 < 5.
# Peak at period 143.55 days was identified to be an alias of 35.14 days at mult 4.00 by tolerance 0.02.
# Period of 383.72 days has SNR of 3.5422712355049164 < 5.
# Period of 84.42 days has SNR of 4.945329716322768 < 5.
# Peak at period 35.87 days was identified to be an alias of 35.14 days at mult 1.00 by tolerance 0.02.
# Peak at period 669.51 days was identified to be an alias of 1326.52 days at mult 0.50 by tolerance 0.01.
# Peak at period 72.37 days was identified to be an alias of 35.14 days at mult 2.00 by tolerance 0.03.
# Peak at period 90.62 days was identified to be a window of 91.31 days by tolerance 0.01.
# Peak at period 114.71 days was identified to be an alias of 39.52 days at mult 3.00 by tolerance 0.03.
# Peak at period 73.83 days was identified to be an alias of 227.86 days at mult 0.33 by tolerance 0.03.
# Iteration 6 did not find a frequency: terminating loop.
# The best params were found for 2sm with NLPD of -1.3537549240798443.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0446 | 5.00 |   35.57    |     0.10    |
# | 0.1071 | 5.00 |  2180.50   |     5.97    |
# +--------+------+------------+-------------+
# 6/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2619.36 days was accepted.
# Peak at period 1349.51 days was identified to be an alias of 2619.36 days at mult 0.50 by tolerance 0.03.
# In iteration 1, period at 11306.42 days was accepted.
# Peak at period 1363.02 days was identified to be an alias of 2619.36 days at mult 0.50 by tolerance 0.04.
# In iteration 2, period at 498.69 days was accepted.
# Peak at period 1370.32 days was identified to be an alias of 2619.36 days at mult 0.50 by tolerance 0.05.
# In iteration 3, period at 289.55 days was accepted.
# Peak at period 1913.81 days was identified to be an alias of 498.69 days at mult 4.00 by tolerance 0.04.
# In iteration 4, period at 35.87 days was accepted.
# Peak at period 1915.63 days was identified to be an alias of 498.69 days at mult 4.00 by tolerance 0.04.
# Peak at period 115.81 days was identified to be a window of 121.75 days by tolerance 0.05.
# In iteration 5, period at 38.79 days was accepted.
# Peak at period 1914.17 days was identified to be an alias of 498.69 days at mult 4.00 by tolerance 0.04.
# Peak at period 115.81 days was identified to be an alias of 38.79 days at mult 3.00 by tolerance 0.00.
# In iteration 6, period at 41.35 days was accepted.
# Peak at period 1907.60 days was identified to be an alias of 498.69 days at mult 4.00 by tolerance 0.04.
# Peak at period 115.81 days was identified to be an alias of 38.79 days at mult 3.00 by tolerance 0.00.
# Peak at period 68.72 days was identified to be an alias of 35.87 days at mult 2.00 by tolerance 0.04.
# Peak at period 672.43 days was identified to be an alias of 2619.36 days at mult 0.25 by tolerance 0.03.
# In iteration 7, period at 3463.25 days was accepted.
# Peak at period 115.81 days was identified to be an alias of 38.79 days at mult 3.00 by tolerance 0.00.
# Peak at period 955.31 days was identified to be an alias of 498.69 days at mult 2.00 by tolerance 0.04.
# In iteration 8, period at 778.65 days was accepted.
# Peak at period 115.81 days was identified to be an alias of 38.79 days at mult 3.00 by tolerance 0.00.
# Peak at period 170.92 days was identified to be an alias of 498.69 days at mult 0.33 by tolerance 0.03.
# Peak at period 68.36 days was identified to be an alias of 35.87 days at mult 2.00 by tolerance 0.05.
# Period of 66.17 days has SNR of 4.464243357277164 < 5.
# In iteration 9, period at 1868.91 days was accepted.
# Peak at period 170.56 days was identified to be an alias of 498.69 days at mult 0.33 by tolerance 0.03.
# In iteration 10, period at 66.17 days was accepted.
# Peak at period 170.56 days was identified to be an alias of 498.69 days at mult 0.33 by tolerance 0.03.
# Peak at period 68.36 days was identified to be an alias of 35.87 days at mult 2.00 by tolerance 0.05.
# Peak at period 115.81 days was identified to be an alias of 38.79 days at mult 3.00 by tolerance 0.00.
# Peak at period 83.69 days was identified to be an alias of 41.35 days at mult 2.00 by tolerance 0.01.
# Peak at period 118.36 days was identified to be an alias of 38.79 days at mult 3.00 by tolerance 0.02.
# Peak at period 30.40 days was identified to be a window of 30.44 days by tolerance 0.00.
# Iteration 11 did not find a frequency: terminating loop.
# The best params were found for 2sm with NLPD of -1.2857745652587445.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0521 | 5.00 |   34.91    |     0.10    |
# | 0.1201 | 5.00 |  2357.42   |     6.46    |
# +--------+------+------------+-------------+
# 7/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2748.57 days was accepted.
# In iteration 1, period at 13172.68 days was accepted.
# Peak at period 1375.06 days was identified to be an alias of 2748.57 days at mult 0.50 by tolerance 0.00.
# In iteration 2, period at 497.60 days was accepted.
# Peak at period 1377.25 days was identified to be an alias of 2748.57 days at mult 0.50 by tolerance 0.00.
# In iteration 3, period at 290.28 days was accepted.
# Peak at period 2019.66 days was identified to be an alias of 497.60 days at mult 4.00 by tolerance 0.01.
# In iteration 4, period at 35.87 days was accepted.
# Peak at period 2025.13 days was identified to be an alias of 497.60 days at mult 4.00 by tolerance 0.02.
# Peak at period 251.95 days was identified to be an alias of 497.60 days at mult 0.50 by tolerance 0.01.
# In iteration 5, period at 769.89 days was accepted.
# Peak at period 2014.55 days was identified to be an alias of 497.60 days at mult 4.00 by tolerance 0.01.
# Peak at period 115.81 days was identified to be a window of 121.75 days by tolerance 0.05.
# Peak at period 35.14 days was identified to be an alias of 35.87 days at mult 1.00 by tolerance 0.02.
# Period of 41.35 days has SNR of 4.788870564804753 < 5.
# Period of 38.79 days has SNR of 4.523883091832881 < 5.
# Peak at period 118.73 days was identified to be an alias of 497.60 days at mult 0.25 by tolerance 0.05.
# Period of 78.58 days has SNR of 3.7095740836345477 < 5.
# Period of 33.68 days has SNR of 3.985442662296764 < 5.
# Period of 66.17 days has SNR of 3.5599877156528312 < 5.
# Peak at period 175.67 days was identified to be a window of 182.62 days by tolerance 0.04.
# Peak at period 170.19 days was identified to be an alias of 497.60 days at mult 0.33 by tolerance 0.03.
# Period of 65.07 days has SNR of 3.257446762609343 < 5.
# Period of 27.11 days has SNR of 3.2924496888027384 < 5.
# Peak at period 36.24 days was identified to be an alias of 35.87 days at mult 1.00 by tolerance 0.01.
# Period of 156.32 days has SNR of 3.6456962212313178 < 5.
# Peak at period 30.40 days was identified to be a window of 30.44 days by tolerance 0.00.
# Peak at period 28.21 days was identified to be a window of 29.50 days by tolerance 0.04.
# Period of 44.63 days has SNR of 3.140041550779903 < 5.
# Peak at period 68.72 days was identified to be an alias of 35.87 days at mult 2.00 by tolerance 0.04.
# Iteration 6 did not find a frequency: terminating loop.
# The best params were found for 2sm with NLPD of -1.1696372834440483.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0497 | 5.00 |   32.28    |     0.09    |
# | 0.1325 | 5.00 |  2473.71   |     6.78    |
# +--------+------+------------+-------------+
# 8/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2719.37 days was accepted.
# Peak at period 10592.48 days was identified to be an alias of 2719.37 days at mult 4.00 by tolerance 0.03.
# Peak at period 1381.27 days was identified to be an alias of 2719.37 days at mult 0.50 by tolerance 0.02.
# Peak at period 379.70 days was identified to be a window of 365.25 days by tolerance 0.04.
# In iteration 1, period at 1815.26 days was accepted.
# In iteration 2, period at 14027.52 days was accepted.
# Peak at period 1352.80 days was identified to be an alias of 2719.37 days at mult 0.50 by tolerance 0.01.
# In iteration 3, period at 1089.63 days was accepted.
# In iteration 4, period at 487.74 days was accepted.
# In iteration 5, period at 36.97 days was accepted.
# In iteration 6, period at 39.89 days was accepted.
# Peak at period 35.14 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.05.
# Peak at period 176.40 days was identified to be a window of 182.62 days by tolerance 0.03.
# Peak at period 119.46 days was identified to be an alias of 487.74 days at mult 0.25 by tolerance 0.02.
# Peak at period 180.05 days was identified to be a window of 182.62 days by tolerance 0.01.
# Period of 33.32 days has SNR of 4.156436013973782 < 5.
# Period of 65.44 days has SNR of 4.022720266246528 < 5.
# Peak at period 30.40 days was identified to be a window of 30.44 days by tolerance 0.00.
# Period of 66.17 days has SNR of 3.756034757429946 < 5.
# Period of 32.22 days has SNR of 3.8962607435398398 < 5.
# Peak at period 36.60 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.01.
# Peak at period 94.27 days was identified to be a window of 91.31 days by tolerance 0.03.
# Period of 222.02 days has SNR of 3.2106365846491784 < 5.
# Peak at period 80.04 days was identified to be an alias of 39.89 days at mult 2.00 by tolerance 0.00.
# Period of 68.72 days has SNR of 3.2748410685170444 < 5.
# Period of 27.48 days has SNR of 3.2179325070377907 < 5.
# Peak at period 13.61 days was identified to be an alias of 39.89 days at mult 0.33 by tolerance 0.02.
# Iteration 7 did not find a frequency: terminating loop.
# The best params were found for 3sml with NLPD of -1.1775553210283567.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0631 | 5.00 |   35.90    |     0.10    |
# | 0.0948 | 5.00 |  2447.43   |     6.71    |
# | 0.0305 | 5.00 |  15430.27  |    42.27    |
# +--------+------+------------+-------------+
# 9/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2739.08 days was accepted.
# In iteration 1, period at 12221.48 days was accepted.
# Peak at period 1368.86 days was identified to be an alias of 2739.08 days at mult 0.50 by tolerance 0.00.
# In iteration 2, period at 505.99 days was accepted.
# Peak at period 1387.84 days was identified to be an alias of 2739.08 days at mult 0.50 by tolerance 0.01.
# In iteration 3, period at 291.01 days was accepted.
# In iteration 4, period at 36.97 days was accepted.
# Peak at period 2041.56 days was identified to be an alias of 505.99 days at mult 4.00 by tolerance 0.01.
# In iteration 5, period at 445.04 days was accepted.
# In iteration 6, period at 156.32 days was accepted.
# Peak at period 39.89 days was identified to be an alias of 156.32 days at mult 0.25 by tolerance 0.02.
# Peak at period 35.87 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.03.
# In iteration 7, period at 33.32 days was accepted.
# Peak at period 35.87 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.03.
# Peak at period 39.89 days was identified to be an alias of 156.32 days at mult 0.25 by tolerance 0.02.
# Peak at period 38.79 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.05.
# Peak at period 35.14 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.05.
# Peak at period 252.32 days was identified to be an alias of 505.99 days at mult 0.50 by tolerance 0.00.
# Peak at period 68.72 days was identified to be an alias of 33.32 days at mult 2.00 by tolerance 0.03.
# Peak at period 166.54 days was identified to be an alias of 505.99 days at mult 0.33 by tolerance 0.01.
# Peak at period 66.17 days was identified to be an alias of 33.32 days at mult 2.00 by tolerance 0.01.
# Peak at period 1117.01 days was identified to be an alias of 291.01 days at mult 4.00 by tolerance 0.04.
# Peak at period 115.08 days was identified to be an alias of 36.97 days at mult 3.00 by tolerance 0.04.
# Peak at period 78.94 days was identified to be an alias of 156.32 days at mult 0.50 by tolerance 0.01.
# Peak at period 40.62 days was identified to be an alias of 156.32 days at mult 0.25 by tolerance 0.04.
# Iteration 8 did not find a frequency: terminating loop.
# The best params were found for 2sm with NLPD of -1.3234534033560208.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0601 | 5.00 |   33.27    |     0.09    |
# | 0.1053 | 5.00 |  2465.17   |     6.75    |
# +--------+------+------------+-------------+
# 10/10
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2721.19 days was accepted.
# In iteration 1, period at 13495.71 days was accepted.
# Peak at period 1398.43 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.03.
# In iteration 2, period at 494.31 days was accepted.
# In iteration 3, period at 1117.74 days was accepted.
# Peak at period 1902.13 days was identified to be an alias of 494.31 days at mult 4.00 by tolerance 0.04.
# In iteration 4, period at 36.97 days was accepted.
# Peak at period 1905.41 days was identified to be an alias of 494.31 days at mult 4.00 by tolerance 0.04.
# Peak at period 1413.39 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.04.
# In iteration 5, period at 306.70 days was accepted.
# In iteration 6, period at 40.62 days was accepted.
# Peak at period 1971.11 days was identified to be an alias of 494.31 days at mult 4.00 by tolerance 0.00.
# Peak at period 172.75 days was identified to be an alias of 494.31 days at mult 0.33 by tolerance 0.05.
# In iteration 7, period at 447.59 days was accepted.
# Peak at period 1386.38 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.02.
# Period of 264.36 days has SNR of 4.459617873667965 < 5.
# Peak at period 221.66 days was identified to be an alias of 447.59 days at mult 0.50 by tolerance 0.01.
# Peak at period 35.87 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.03.
# Peak at period 253.05 days was identified to be an alias of 494.31 days at mult 0.50 by tolerance 0.02.
# Peak at period 172.75 days was identified to be an alias of 494.31 days at mult 0.33 by tolerance 0.05.
# Peak at period 155.59 days was identified to be an alias of 306.70 days at mult 0.50 by tolerance 0.01.
# Peak at period 39.89 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.02.
# Peak at period 153.04 days was identified to be an alias of 36.97 days at mult 4.00 by tolerance 0.03.
# Peak at period 584.10 days was identified to be an alias of 1117.74 days at mult 0.50 by tolerance 0.05.
# Peak at period 40.98 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.01.
# Peak at period 292.10 days was identified to be an alias of 1117.74 days at mult 0.25 by tolerance 0.05.
# Period of 65.44 days has SNR of 3.727209363755065 < 5.
# Peak at period 78.94 days was identified to be an alias of 306.70 days at mult 0.25 by tolerance 0.03.
# Peak at period 19.08 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.03.
# Peak at period 35.14 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.05.
# Period of 34.05 days has SNR of 3.5088090528237537 < 5.
# Period of 68.72 days has SNR of 3.477695554273409 < 5.
# Peak at period 706.38 days was identified to be an alias of 2721.19 days at mult 0.25 by tolerance 0.04.
# Peak at period 235.89 days was identified to be an alias of 494.31 days at mult 0.50 by tolerance 0.05.
# Peak at period 17.62 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.05.
# In iteration 8, period at 778.65 days was accepted.
# Peak at period 1388.94 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.02.
# Peak at period 222.02 days was identified to be an alias of 447.59 days at mult 0.50 by tolerance 0.01.
# Peak at period 35.87 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.03.
# Peak at period 39.89 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.02.
# Peak at period 172.38 days was identified to be an alias of 494.31 days at mult 0.33 by tolerance 0.05.
# Peak at period 264.73 days was identified to be an alias of 778.65 days at mult 0.33 by tolerance 0.02.
# Peak at period 584.83 days was identified to be an alias of 1117.74 days at mult 0.50 by tolerance 0.05.
# Peak at period 35.14 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.05.
# Peak at period 78.94 days was identified to be an alias of 306.70 days at mult 0.25 by tolerance 0.03.
# Peak at period 40.98 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.01.
# Peak at period 153.04 days was identified to be an alias of 36.97 days at mult 4.00 by tolerance 0.03.
# Peak at period 19.08 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.03.
# Period of 65.44 days has SNR of 3.551073747160637 < 5.
# Peak at period 292.47 days was identified to be an alias of 1117.74 days at mult 0.25 by tolerance 0.05.
# Period of 33.32 days has SNR of 3.419110672325683 < 5.
# Peak at period 155.59 days was identified to be an alias of 306.70 days at mult 0.50 by tolerance 0.01.
# Period of 68.72 days has SNR of 3.341871338190637 < 5.
# Period of 138.44 days has SNR of 3.2403158492482413 < 5.
# Peak at period 17.62 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.05.
# Period of 32.22 days has SNR of 3.1802552280893512 < 5.
# Period of 16.89 days has SNR of 3.0728056939010813 < 5.
# Peak at period 29.67 days was identified to be a window of 30.44 days by tolerance 0.03.
# Peak at period 30.40 days was identified to be a window of 30.44 days by tolerance 0.00.
# Period of 34.05 days has SNR of 2.987408279141171 < 5.
# Period of 66.17 days has SNR of 2.9743855616715478 < 5.
# Peak at period 181.87 days was identified to be a window of 182.62 days by tolerance 0.00.
# Peak at period 93.91 days was identified to be a window of 91.31 days by tolerance 0.03.
# Iteration 9 did not find a frequency: terminating loop.
# The best params were found for 2sm with NLPD of -1.1292473643119862.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0600 | 5.00 |   36.55    |     0.10    |
# | 0.1063 | 5.00 |  2449.08   |     6.71    |
# +--------+------+------------+-------------+
