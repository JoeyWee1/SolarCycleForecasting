# %% [markdown]
# # Pipeline Moving Window
# - Here, we perform moving window analysis using the pipeline code fit at various datasplits.

# %%
# Importing and data hopo hopo
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
from pathlib import Path

sys.path.append(str(Path('../..').resolve()))
from helpers.gpr import train_gpr

# %%
def plot_moving_window( n_windows = 5, train_low = 0.1, train_high = 0.9):
    fig, ax = plt.subplots(n_windows, 1, figsize=(20, 5 * n_windows), sharex= True, sharey= True)
    train_splits = np.linspace(train_low, train_high, n_windows)       

    for idx, train_split in enumerate(train_splits):
        print(f"{idx+1}/{n_windows}")
        valid_split = 0.99 - train_split
        best_gp = train_gpr(
        datapath    =  r"../../Data/benchmark/HD201091_Mt_wilson_data.txt",
        train_split=train_split,
        valid_split=valid_split,
        star_name   = 'HD201091',
        star_type   = 'G',
        add_prefix  = False,
        relative=True,
        verbose          = False,
        plot             = False,
        loop_verbose     = False,
        loop_plot        = True,
        loop_savefigs    = True,   # show inline rather than saving
        results_verbose  = True,
        results_plot     = True,
        require_mid=True,
        ax = ax[idx]
    )
    
    plt.show()

plot_moving_window()
# Out:
# 1/5
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2551.47 days was accepted.
# In iteration 1, period at 39.52 days was accepted.
# In iteration 2, period at 37.33 days was accepted.
# The best params were found for 3sml with NLPD of -1.0470004769310737.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0404 | 5.00 |   36.95    |     0.10    |
# | 0.1140 | 5.00 |  2296.32   |     6.29    |
# | 0.0001 | 5.00 |  32850.00  |    90.00    |
# +--------+------+------------+-------------+
# 2/5
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2215.67 days was accepted.
# Peak at period 4461.89 days was identified to be an alias of 2215.67 days at mult 2.00 by tolerance 0.01.
# In iteration 1, period at 39.52 days was accepted.
# Peak at period 4454.96 days was identified to be an alias of 2215.67 days at mult 2.00 by tolerance 0.01.
# In iteration 2, period at 392.48 days was accepted.
# Peak at period 4290.34 days was identified to be an alias of 2215.67 days at mult 2.00 by tolerance 0.03.
# Period of 331.89 days has SNR of 4.42047971414579 < 5.
# In iteration 3, period at 643.96 days was accepted.
# Peak at period 4275.01 days was identified to be an alias of 2215.67 days at mult 2.00 by tolerance 0.04.
# Peak at period 331.52 days was identified to be an alias of 643.96 days at mult 0.50 by tolerance 0.03.
# In iteration 4, period at 33.68 days was accepted.
# Peak at period 4337.06 days was identified to be an alias of 2215.67 days at mult 2.00 by tolerance 0.02.
# Peak at period 331.89 days was identified to be an alias of 643.96 days at mult 0.50 by tolerance 0.03.
# Peak at period 188.81 days was identified to be an alias of 392.48 days at mult 0.50 by tolerance 0.04.
# In iteration 5, period at 26.75 days was accepted.
# Peak at period 4362.25 days was identified to be an alias of 2215.67 days at mult 2.00 by tolerance 0.02.
# Peak at period 332.62 days was identified to be an alias of 643.96 days at mult 0.50 by tolerance 0.03.
# Peak at period 189.17 days was identified to be an alias of 392.48 days at mult 0.50 by tolerance 0.04.
# Peak at period 97.19 days was identified to be an alias of 392.48 days at mult 0.25 by tolerance 0.01.
# In iteration 6, period at 1684.22 days was accepted.
# Peak at period 4631.25 days was identified to be an alias of 2215.67 days at mult 2.00 by tolerance 0.05.
# Peak at period 189.54 days was identified to be an alias of 392.48 days at mult 0.50 by tolerance 0.03.
# Peak at period 335.17 days was identified to be an alias of 643.96 days at mult 0.50 by tolerance 0.04.
# Peak at period 127.12 days was identified to be an alias of 392.48 days at mult 0.33 by tolerance 0.03.
# Peak at period 96.83 days was identified to be an alias of 392.48 days at mult 0.25 by tolerance 0.01.
# Period of 46.46 days has SNR of 4.69614236485644 < 5.
# Peak at period 1291.11 days was identified to be an alias of 643.96 days at mult 2.00 by tolerance 0.00.
# Period of 72.74 days has SNR of 3.8667106638650406 < 5.
# Period of 23.46 days has SNR of 4.163472320801578 < 5.
# Iteration 7 did not find a frequency: terminating loop.
# The best params were found for 3sml with NLPD of -0.7746830514118634.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0423 | 5.00 |   35.57    |     0.10    |
# | 0.0975 | 5.00 |  2132.60   |     5.84    |
# | 0.0001 | 5.00 |  32850.01  |    90.00    |
# +--------+------+------------+-------------+
# 3/5
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2566.07 days was accepted.
# Peak at period 1337.10 days was identified to be an alias of 2566.07 days at mult 0.50 by tolerance 0.04.
# Peak at period 10559.26 days was identified to be an alias of 2566.07 days at mult 4.00 by tolerance 0.03.
# In iteration 1, period at 498.33 days was accepted.
# Peak at period 10694.31 days was identified to be an alias of 2566.07 days at mult 4.00 by tolerance 0.04.
# Peak at period 351.96 days was identified to be a window of 365.25 days by tolerance 0.04.
# Peak at period 1338.56 days was identified to be an alias of 2566.07 days at mult 0.50 by tolerance 0.04.
# In iteration 2, period at 274.22 days was accepted.
# In iteration 3, period at 9332.49 days was accepted.
# In iteration 4, period at 35.87 days was accepted.
# Peak at period 1911.98 days was identified to be an alias of 498.33 days at mult 4.00 by tolerance 0.04.
# In iteration 5, period at 685.57 days was accepted.
# Peak at period 1915.27 days was identified to be an alias of 498.33 days at mult 4.00 by tolerance 0.04.
# In iteration 6, period at 41.35 days was accepted.
# Peak at period 1910.16 days was identified to be an alias of 498.33 days at mult 4.00 by tolerance 0.04.
# Peak at period 34.78 days was identified to be an alias of 35.87 days at mult 1.00 by tolerance 0.03.
# Peak at period 1329.07 days was identified to be an alias of 2566.07 days at mult 0.50 by tolerance 0.04.
# Peak at period 115.81 days was identified to be a window of 121.75 days by tolerance 0.05.
# Period of 27.11 days has SNR of 4.679116308826009 < 5.
# Peak at period 68.72 days was identified to be an alias of 274.22 days at mult 0.25 by tolerance 0.00.
# Period of 16.89 days has SNR of 4.61932003035772 < 5.
# Peak at period 17.99 days was identified to be an alias of 35.87 days at mult 0.50 by tolerance 0.00.
# Peak at period 66.17 days was identified to be an alias of 274.22 days at mult 0.25 by tolerance 0.03.
# In iteration 7, period at 3350.09 days was accepted.
# Peak at period 34.78 days was identified to be an alias of 35.87 days at mult 1.00 by tolerance 0.03.
# Peak at period 68.72 days was identified to be an alias of 274.22 days at mult 0.25 by tolerance 0.00.
# Peak at period 115.81 days was identified to be a window of 121.75 days by tolerance 0.05.
# Peak at period 1303.16 days was identified to be an alias of 2566.07 days at mult 0.50 by tolerance 0.02.
# Peak at period 66.17 days was identified to be an alias of 274.22 days at mult 0.25 by tolerance 0.03.
# Period of 27.11 days has SNR of 4.313339642798481 < 5.
# Period of 16.89 days has SNR of 3.967512753573772 < 5.
# Peak at period 532.64 days was identified to be an alias of 274.22 days at mult 2.00 by tolerance 0.03.
# In iteration 8, period at 945.46 days was accepted.
# Peak at period 34.78 days was identified to be an alias of 35.87 days at mult 1.00 by tolerance 0.03.
# Peak at period 115.81 days was identified to be a window of 121.75 days by tolerance 0.05.
# In iteration 9, period at 27.11 days was accepted.
# Peak at period 34.78 days was identified to be an alias of 35.87 days at mult 1.00 by tolerance 0.03.
# Peak at period 115.81 days was identified to be a window of 121.75 days by tolerance 0.05.
# Peak at period 68.72 days was identified to be an alias of 274.22 days at mult 0.25 by tolerance 0.00.
# Peak at period 170.19 days was identified to be an alias of 498.33 days at mult 0.33 by tolerance 0.02.
# Peak at period 31.86 days was identified to be a window of 30.44 days by tolerance 0.05.
# Period of 38.79 days has SNR of 4.450909323667213 < 5.
# Peak at period 118.36 days was identified to be an alias of 498.33 days at mult 0.25 by tolerance 0.05.
# Peak at period 17.99 days was identified to be an alias of 35.87 days at mult 0.50 by tolerance 0.00.
# Period of 16.89 days has SNR of 3.563258487483274 < 5.
# Peak at period 84.05 days was identified to be an alias of 41.35 days at mult 2.00 by tolerance 0.02.
# Peak at period 82.23 days was identified to be an alias of 41.35 days at mult 2.00 by tolerance 0.01.
# Peak at period 66.17 days was identified to be an alias of 274.22 days at mult 0.25 by tolerance 0.03.
# Iteration 10 did not find a frequency: terminating loop.
# The best params were found for 3sml with NLPD of -1.358832924829697.
# +--------+--------+------------+-------------+
# | sigma  |   Q    | rho (days) | rho (years) |
# +--------+--------+------------+-------------+
# | 0.0513 |  5.00  |   37.21    |     0.10    |
# | 0.0943 |  5.00  |  2309.46   |     6.33    |
# | 0.0336 | 100.00 |  10265.74  |    28.13    |
# +--------+--------+------------+-------------+
# 4/5
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2717.54 days was accepted.
# Peak at period 10664.02 days was identified to be an alias of 2717.54 days at mult 4.00 by tolerance 0.02.
# Peak at period 1378.35 days was identified to be an alias of 2717.54 days at mult 0.50 by tolerance 0.01.
# In iteration 1, period at 496.14 days was accepted.
# In iteration 2, period at 12027.67 days was accepted.
# Peak at period 1356.45 days was identified to be an alias of 2717.54 days at mult 0.50 by tolerance 0.00.
# In iteration 3, period at 291.01 days was accepted.
# In iteration 4, period at 35.87 days was accepted.
# Peak at period 35.14 days was identified to be an alias of 35.87 days at mult 1.00 by tolerance 0.02.
# Peak at period 2002.14 days was identified to be an alias of 496.14 days at mult 4.00 by tolerance 0.01.
# In iteration 5, period at 38.79 days was accepted.
# Peak at period 2009.07 days was identified to be an alias of 496.14 days at mult 4.00 by tolerance 0.01.
# Period of 33.68 days has SNR of 4.956519948560651 < 5.
# In iteration 6, period at 66.17 days was accepted.
# Peak at period 2016.01 days was identified to be an alias of 496.14 days at mult 4.00 by tolerance 0.02.
# Peak at period 68.72 days was identified to be an alias of 35.87 days at mult 2.00 by tolerance 0.04.
# In iteration 7, period at 40.98 days was accepted.
# Peak at period 2008.34 days was identified to be an alias of 496.14 days at mult 4.00 by tolerance 0.01.
# Peak at period 68.72 days was identified to be an alias of 35.87 days at mult 2.00 by tolerance 0.04.
# Peak at period 37.70 days was identified to be an alias of 38.79 days at mult 1.00 by tolerance 0.03.
# Peak at period 156.69 days was identified to be an alias of 38.79 days at mult 4.00 by tolerance 0.01.
# Peak at period 949.84 days was identified to be an alias of 2717.54 days at mult 0.33 by tolerance 0.05.
# Peak at period 251.22 days was identified to be an alias of 496.14 days at mult 0.50 by tolerance 0.01.
# Peak at period 33.68 days was identified to be an alias of 66.17 days at mult 0.50 by tolerance 0.02.
# Peak at period 595.05 days was identified to be an alias of 291.01 days at mult 2.00 by tolerance 0.02.
# Peak at period 270.93 days was identified to be an alias of 66.17 days at mult 4.00 by tolerance 0.02.
# Peak at period 30.40 days was identified to be a window of 30.44 days by tolerance 0.00.
# In iteration 8, period at 761.50 days was accepted.
# Peak at period 2021.48 days was identified to be an alias of 496.14 days at mult 4.00 by tolerance 0.02.
# Peak at period 68.72 days was identified to be an alias of 35.87 days at mult 2.00 by tolerance 0.04.
# Peak at period 33.68 days was identified to be an alias of 66.17 days at mult 0.50 by tolerance 0.02.
# Peak at period 177.13 days was identified to be a window of 182.62 days by tolerance 0.03.
# Peak at period 30.40 days was identified to be a window of 30.44 days by tolerance 0.00.
# Peak at period 591.77 days was identified to be an alias of 291.01 days at mult 2.00 by tolerance 0.02.
# Peak at period 37.70 days was identified to be an alias of 38.79 days at mult 1.00 by tolerance 0.03.
# Peak at period 156.69 days was identified to be an alias of 38.79 days at mult 4.00 by tolerance 0.01.
# Peak at period 969.55 days was identified to be an alias of 496.14 days at mult 2.00 by tolerance 0.02.
# Period of 439.20 days has SNR of 4.200964544074694 < 5.
# Peak at period 84.05 days was identified to be an alias of 40.98 days at mult 2.00 by tolerance 0.03.
# Period of 534.83 days has SNR of 4.110048174123776 < 5.
# Iteration 9 did not find a frequency: terminating loop.
# The best params were found for 3sml with NLPD of -1.2621979157899057.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0613 | 5.00 |   34.91    |     0.10    |
# | 0.0918 | 5.00 |  2445.79   |     6.70    |
# | 0.0338 | 5.00 |  13230.43  |    36.25    |
# +--------+------+------------+-------------+
# 5/5
# C:\Users\Joey\Desktop\Cambridge\Work\Thesis\helpers\LSP_peaks.py:173: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_timeframe = t[-1] - t[0]
# In iteration 0, period at 2721.19 days was accepted.
# In iteration 1, period at 13495.71 days was accepted.
# Peak at period 1398.43 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.03.
# In iteration 2, period at 494.31 days was accepted.
# In iteration 3, period at 1117.74 days was accepted.
# Peak at period 1902.13 days was identified to be an alias of 494.31 days at mult 4.00 by tolerance 0.04.
# In iteration 4, period at 36.97 days was accepted.
# Peak at period 1905.41 days was identified to be an alias of 494.31 days at mult 4.00 by tolerance 0.04.
# Peak at period 1413.39 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.04.
# In iteration 5, period at 306.70 days was accepted.
# In iteration 6, period at 40.62 days was accepted.
# Peak at period 1971.11 days was identified to be an alias of 494.31 days at mult 4.00 by tolerance 0.00.
# Peak at period 172.75 days was identified to be an alias of 494.31 days at mult 0.33 by tolerance 0.05.
# In iteration 7, period at 447.59 days was accepted.
# Peak at period 1386.38 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.02.
# Period of 264.36 days has SNR of 4.459617873667965 < 5.
# Peak at period 221.66 days was identified to be an alias of 447.59 days at mult 0.50 by tolerance 0.01.
# Peak at period 35.87 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.03.
# Peak at period 253.05 days was identified to be an alias of 494.31 days at mult 0.50 by tolerance 0.02.
# Peak at period 172.75 days was identified to be an alias of 494.31 days at mult 0.33 by tolerance 0.05.
# Peak at period 155.59 days was identified to be an alias of 306.70 days at mult 0.50 by tolerance 0.01.
# Peak at period 39.89 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.02.
# Peak at period 153.04 days was identified to be an alias of 36.97 days at mult 4.00 by tolerance 0.03.
# Peak at period 584.10 days was identified to be an alias of 1117.74 days at mult 0.50 by tolerance 0.05.
# Peak at period 40.98 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.01.
# Peak at period 292.10 days was identified to be an alias of 1117.74 days at mult 0.25 by tolerance 0.05.
# Period of 65.44 days has SNR of 3.727209363755065 < 5.
# Peak at period 78.94 days was identified to be an alias of 306.70 days at mult 0.25 by tolerance 0.03.
# Peak at period 19.08 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.03.
# Peak at period 35.14 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.05.
# Period of 34.05 days has SNR of 3.5088090528237537 < 5.
# Period of 68.72 days has SNR of 3.477695554273409 < 5.
# Peak at period 706.38 days was identified to be an alias of 2721.19 days at mult 0.25 by tolerance 0.04.
# Peak at period 235.89 days was identified to be an alias of 494.31 days at mult 0.50 by tolerance 0.05.
# Peak at period 17.62 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.05.
# In iteration 8, period at 778.65 days was accepted.
# Peak at period 1388.94 days was identified to be an alias of 2721.19 days at mult 0.50 by tolerance 0.02.
# Peak at period 222.02 days was identified to be an alias of 447.59 days at mult 0.50 by tolerance 0.01.
# Peak at period 35.87 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.03.
# Peak at period 39.89 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.02.
# Peak at period 172.38 days was identified to be an alias of 494.31 days at mult 0.33 by tolerance 0.05.
# Peak at period 264.73 days was identified to be an alias of 778.65 days at mult 0.33 by tolerance 0.02.
# Peak at period 584.83 days was identified to be an alias of 1117.74 days at mult 0.50 by tolerance 0.05.
# Peak at period 35.14 days was identified to be an alias of 36.97 days at mult 1.00 by tolerance 0.05.
# Peak at period 78.94 days was identified to be an alias of 306.70 days at mult 0.25 by tolerance 0.03.
# Peak at period 40.98 days was identified to be an alias of 40.62 days at mult 1.00 by tolerance 0.01.
# Peak at period 153.04 days was identified to be an alias of 36.97 days at mult 4.00 by tolerance 0.03.
# Peak at period 19.08 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.03.
# Period of 65.44 days has SNR of 3.551073747160637 < 5.
# Peak at period 292.47 days was identified to be an alias of 1117.74 days at mult 0.25 by tolerance 0.05.
# Period of 33.32 days has SNR of 3.419110672325683 < 5.
# Peak at period 155.59 days was identified to be an alias of 306.70 days at mult 0.50 by tolerance 0.01.
# Period of 68.72 days has SNR of 3.341871338190637 < 5.
# Period of 138.44 days has SNR of 3.2403158492482413 < 5.
# Peak at period 17.62 days was identified to be an alias of 36.97 days at mult 0.50 by tolerance 0.05.
# Period of 32.22 days has SNR of 3.1802552280893512 < 5.
# Period of 16.89 days has SNR of 3.0728056939010813 < 5.
# Peak at period 29.67 days was identified to be a window of 30.44 days by tolerance 0.03.
# Peak at period 30.40 days was identified to be a window of 30.44 days by tolerance 0.00.
# Period of 34.05 days has SNR of 2.987408279141171 < 5.
# Period of 66.17 days has SNR of 2.9743855616715478 < 5.
# Peak at period 181.87 days was identified to be a window of 182.62 days by tolerance 0.00.
# Peak at period 93.91 days was identified to be a window of 91.31 days by tolerance 0.03.
# Iteration 9 did not find a frequency: terminating loop.
# The best params were found for 2sm with NLPD of -1.1292473643119862.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0600 | 5.00 |   36.55    |     0.10    |
# | 0.1063 | 5.00 |  2449.08   |     6.71    |
# +--------+------+------------+-------------+
