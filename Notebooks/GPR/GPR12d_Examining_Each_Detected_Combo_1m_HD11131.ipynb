# %% [markdown]
# # Examining how the pipeline performs with each detected combination.
#
# - Let's examine one of each manually and make the pipeline work for them.
# - 3sml: hd18256
# - 2sm: hd10072
# - 2ml: hd16673
# - 1m: hd11131
# - 0: hd10700

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import minimize

import celerite2
from celerite2 import terms

from prettytable import PrettyTable

import sys
from pathlib import Path

sys.path.append(str(Path('../..').resolve()))

from helpers.df_ops import prepare_df, split_df, clean_df
from helpers.priors import find_classify_signals, get_priors

SEED = 1701
error_percent = 5

# %%
from helpers.gpr import train_gpr

datapath = r"../../Data/hd11131_caii.txt"
add_prefix = True
relative = True
train_split = 0.8
valid_split = 0.19

require_mid = True
sigma_upper_mult = 5
rho_bound_mults = [0.9, 1.1]
q_bounds_in = [5, 10]
loop_verbose = False
loop_plot = False
loop_savefigs = False
star_name = "HD11131"
star_type = "G"
results_verbose = True
results_plot = True
ax = None

# Window analysis using refactored train_gpr
def plot_moving_window(n_windows=10, train_low=0.1, train_high=0.9):
    fig, axes = plt.subplots(n_windows, 1, figsize=(20, 5 * n_windows), sharex=True, sharey=True)
    train_splits = np.linspace(train_low, train_high, n_windows)

    for idx, ts in enumerate(train_splits):
        print(f"{idx+1}/{n_windows}")
        train_gpr(
            datapath         = datapath,
            add_prefix       = add_prefix,
            relative         = relative,
            train_split      = ts,
            valid_split      = 0.99 - ts,
            star_name        = star_name,
            star_type        = star_type,
            error_percent    = error_percent,
            sigma_upper_mult = sigma_upper_mult,
            q_bounds_in      = q_bounds_in,
            require_mid      = require_mid,
            verbose          = False,
            plot             = False,
            loop_verbose     = loop_verbose,
            loop_plot        = loop_plot,
            loop_savefigs    = loop_savefigs,
            results_verbose  = results_verbose,
            results_plot     = results_plot,
            ax               = axes[idx],
            SEED             = SEED,
        )

    plt.tight_layout()
    plt.savefig(f"moving_window_{star_name}")
    plt.show()

plot_moving_window()
# Out:
# 1/10
# The best params were found for 1m with NLPD of -2.6396867572586493.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0001 | 5.00 |  2495.11   |     6.84    |
# +--------+------+------------+-------------+
# 2/10
# The best params were found for const with NLPD of -2.7070021845537475.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0015 | 0.50 |   616.69   |     1.69    |
# +--------+------+------------+-------------+
# 3/10
# The best params were found for 1m with NLPD of -2.8856789735220847.
# +--------+-------+------------+-------------+
# | sigma  |   Q   | rho (days) | rho (years) |
# +--------+-------+------------+-------------+
# | 0.0039 | 10.00 |  1431.89   |     3.92    |
# +--------+-------+------------+-------------+
# 4/10
# The best params were found for const with NLPD of -2.8731168213975535.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0054 | 0.50 |   817.40   |     2.24    |
# +--------+------+------------+-------------+
# 5/10
# The best params were found for 1m with NLPD of -3.008324349131168.
# +--------+-------+------------+-------------+
# | sigma  |   Q   | rho (days) | rho (years) |
# +--------+-------+------------+-------------+
# | 0.0078 | 10.00 |   531.51   |     1.46    |
# +--------+-------+------------+-------------+
# 6/10
# The best params were found for const with NLPD of -2.988638979671416.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0150 | 0.50 |  1222.78   |     3.35    |
# +--------+------+------------+-------------+
# 7/10
# The best params were found for 1m with NLPD of -2.9817664539172792.
# +--------+-------+------------+-------------+
# | sigma  |   Q   | rho (days) | rho (years) |
# +--------+-------+------------+-------------+
# | 0.0078 | 10.00 |   320.51   |     0.88    |
# +--------+-------+------------+-------------+
# 8/10
# The best params were found for 2ml with NLPD of -2.9411343032680493.
# +--------+-------+------------+-------------+
# | sigma  |   Q   | rho (days) | rho (years) |
# +--------+-------+------------+-------------+
# | 0.0105 | 10.00 |   518.85   |     1.42    |
# | 0.0020 |  5.00 |  36028.84  |    98.71    |
# +--------+-------+------------+-------------+
# 9/10
# The best params were found for const with NLPD of -2.941027702629134.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0148 | 0.50 |   922.85   |     2.53    |
# +--------+------+------------+-------------+
# 10/10
# The best params were found for const with NLPD of -3.0117720206686363.
# +--------+------+------------+-------------+
# | sigma  |  Q   | rho (days) | rho (years) |
# +--------+------+------------+-------------+
# | 0.0111 | 0.50 |   451.36   |     1.24    |
# +--------+------+------------+-------------+

# %% [markdown]
# - Once again, I think it is important to introduce a factor of the model uncertainty using an MCMC.
